# %%
import pandas as pd

# %%
# %matplotlib inline
from IPython.display import Image

# %%
#https://innodata.com/ethical-issues-in-computer-vision-and-strategies-for-success/#:~:text=Because%20computer%20vision%20enables%20artificial,the%20lack%20of%20informed%20consent.

# %%
Image('descarga.png')

# %%
# my input was - a man sitting on a fence

# %%
# i feel the machine as done averagely good in trying to show an image which looks like a man and also a fence

# %%
# https://thedatafrog.com/en/articles/dogs-vs-cats/

# %%
#To get a close look at the dataset and be able to clean up bad pictures, he used a fast image browser to check all images in the dogs and cats directories. .
